# %% [markdown]
# # Importing and Setting up the API

# %%
# Note: this was necessary even though I installed spotipy via my cmd because the shell and this kernel use different versions
# of python. So in order to install spotipy here, we need to install it using sys.executable and not regular python3.
import sys
# !{sys.executable} -m pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\neela\anaconda3\lib\site-packages (2.20.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\neela\anaconda3\lib\site-packages (from spotipy) (1.26.9)
# Requirement already satisfied: requests>=2.25.0 in c:\users\neela\anaconda3\lib\site-packages (from spotipy) (2.27.1)
# Requirement already satisfied: six>=1.15.0 in c:\users\neela\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\neela\anaconda3\lib\site-packages (from spotipy) (4.3.4)
# Requirement already satisfied: packaging>=20.4 in c:\users\neela\anaconda3\lib\site-packages (from redis>=3.5.3->spotipy) (21.3)
# Requirement already satisfied: deprecated>=1.2.3 in c:\users\neela\anaconda3\lib\site-packages (from redis>=3.5.3->spotipy) (1.2.13)
# Requirement already satisfied: async-timeout>=4.0.2 in c:\users\neela\anaconda3\lib\site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\neela\anaconda3\lib\site-packages (from deprecated>=1.2.3->redis>=3.5.3->spotipy) (1.12.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\neela\anaconda3\lib\site-packages (from packaging>=20.4->redis>=3.5.3->spotipy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\neela\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\neela\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\neela\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# For our web app, we're going to use the **Client Credentials** flow. This project is relatively small in scale, so this flow allows us to access a user's data without the need to implement refresh tokens.

# %%
# Authenticating (without user credentials)
cid = 'f9dba5bfdfe24101b6b7af6fa0ed8ad0'
secret = '6d785aee0418404a9e2b81cb3a802f85'

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
# Random Test
weeknduri = 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ' # you don't need the 'spotify:artist:'
results = sp.artist_top_tracks(weeknduri)
for i, track in enumerate(results['tracks'][:10]):
    print(f'{i+1}. ' + track['name'])
# Out:
# 1. Blinding Lights
# 2. Call Out My Name
# 3. I Was Never There
# 4. Save Your Tears
# 5. Starboy
# 6. The Hills
# 7. Die For You
# 8. Lost in the Fire (feat. The Weeknd)
# 9. Save Your Tears (Remix) (with Ariana Grande) - Bonus Track
# 10. You Right

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"
playlist_URI = playlist_link.split('/')[-1].split('?')[0] # extracts the URI from the link
playlist_URI

track_uris = []
for track in sp.playlist_tracks(playlist_URI)['items']:
    track_uris.append(track['track']['uri'])

# track_uris

# %%
sp.audio_features(track_uris[0])
# Out:
# [{'danceability': 0.621,
#   'energy': 0.782,
#   'key': 2,
#   'loudness': -5.548,
#   'mode': 1,
#   'speechiness': 0.044,
#   'acousticness': 0.0125,
#   'instrumentalness': 0.033,
#   'liveness': 0.23,
#   'valence': 0.55,
#   'tempo': 128.033,
#   'type': 'audio_features',
#   'id': '2tTmW7RDtMQtBk7m2rYeSw',
#   'uri': 'spotify:track:2tTmW7RDtMQtBk7m2rYeSw',
#   'track_href': 'https://api.spotify.com/v1/tracks/2tTmW7RDtMQtBk7m2rYeSw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2tTmW7RDtMQtBk7m2rYeSw',
#   'duration_ms': 198938,
#   'time_signature': 4}]

# %% [markdown]
# # Getting the data

# %%
import pandas as pd
import json

# %%
data_path = 'mpd.slice.0-999.json'
json_dict = json.loads(open(data_path).read()) # json.loads() deserializes a json string and returns a python dictionary

playlists = json_dict['playlists']
df = pd.json_normalize(playlists, record_path='tracks', meta='name') # record_path looks at 'tracks' in every playlist

# df.to_csv('raw_data.csv')
df

# pd.read_json('mpd.slice.0-999.json').head()
# Out:
#        pos        artist_name                             track_uri  \
# 0        0      Missy Elliott  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1        1     Britney Spears  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2        2            Beyoncé  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3        3  Justin Timberlake  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4        4             Shaggy  spotify:track:1lzr43nnXAijIGYnCT8M8H
# ...    ...                ...                                   ...
# 67498   39       James Arthur  spotify:track:5uCax9HTNlzGybIStD3vDh
# 67499   40          Big Words  spotify:track:0P1oO2gREMYUCoOkzYAyFu
# 67500   41       Allan Rayman  spotify:track:2oM4BuruDnEvk59IvIXCwn
# 67501   42          Jon Jason  spotify:track:4Ri5TTUgjM96tbQZd5Ua7V
# 67502   43           Grizfolk  spotify:track:5RVuBrXVLptAEbGJdSDzL5
#
#                                   artist_uri  \
# 0      spotify:artist:2wIVse2owClT7go1WT98tk
# 1      spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 2      spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 3      spotify:artist:31TPClRtHm23RisEBtV3X7
# 4      spotify:artist:5EvFsr3kj42KNv97ZEnqij
# ...                                      ...
# 67498  spotify:artist:4IWBUUAFIplrNtaOHcJPRM
# 67499  spotify:artist:0sHN89qak07mnug3LVVjzP
# 67500  spotify:artist:6Yv6OBXD6ZQakEljaGaDAk
# 67501  spotify:artist:77bNdkKYBBmc30CisCA6tE
# 67502  spotify:artist:6Xa4nbrSTfbioA4lLShbjh
#
#                                          track_name  \
# 0        Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                             Toxic
# 2                                     Crazy In Love
# 3                                    Rock Your Body
# 4                                      It Wasn't Me
# ...                                             ...
# 67498                          Say You Won't Let Go
# 67499                                    The Answer
# 67500                                         25.22
# 67501                                  Good Feeling
# 67502  Cosmic Angel - Acoustic From Capitol Studios
#
#                                   album_uri  duration_ms  \
# 0      spotify:album:6vV5UrXcfyQD1wu4Qo2I9K       226863
# 1      spotify:album:0z7pVBGOD7HCIB7S8eLkLI       198800
# 2      spotify:album:25hVFAxTlDvXbx2X2QkUkE       235933
# 3      spotify:album:6QPkyl04rXwTGlGlcYaRoW       267266
# 4      spotify:album:6NmFmPX56pcLBOFMhIiKvF       227600
# ...                                     ...          ...
# 67498  spotify:album:7oiJYvEJHsmYtrgviAVIBD       211466
# 67499  spotify:album:5jrsRHRAmetu5e7RRBoxj7       263679
# 67500  spotify:album:3CbNgBzI7r9o0F6VjH9sTY       189213
# 67501  spotify:album:2dZ7oVNQBeLlpoUYfbEsJP       194720
# 67502  spotify:album:7D6Y19tjm4DQNch39FeWpO       257194
#
#                                          album_name             name
# 0                                      The Cookbook       Throwbacks
# 1                                       In The Zone       Throwbacks
# 2      Dangerously In Love (Alben für die Ewigkeit)       Throwbacks
# 3                                         Justified       Throwbacks
# 4                                          Hot Shot       Throwbacks
# ...                                             ...              ...
# 67498                            Back from the Edge  thinking of you
# 67499            Hollywood, a Beautiful Coincidence  thinking of you
# 67500                                  Roadhouse 01  thinking of you
# 67501                                  Good Feeling  thinking of you
# 67502                                  Cosmic Angel  thinking of you
#
# [67503 rows x 9 columns]

# %%
# Test
fd = pd.json_normalize(playlists, record_path='tracks')
fd.head()
# Out:
#    pos        artist_name                             track_uri  \
# 0    0      Missy Elliott  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1    1     Britney Spears  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2    2            Beyoncé  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3    3  Justin Timberlake  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4    4             Shaggy  spotify:track:1lzr43nnXAijIGYnCT8M8H
#
#                               artist_uri  \
# 0  spotify:artist:2wIVse2owClT7go1WT98tk
# 1  spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 2  spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 3  spotify:artist:31TPClRtHm23RisEBtV3X7
# 4  spotify:artist:5EvFsr3kj42KNv97ZEnqij
#
#                                    track_name  \
# 0  Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                       Toxic
# 2                               Crazy In Love
# 3                              Rock Your Body
# 4                                It Wasn't Me
#
#                               album_uri  duration_ms  \
# 0  spotify:album:6vV5UrXcfyQD1wu4Qo2I9K       226863
# 1  spotify:album:0z7pVBGOD7HCIB7S8eLkLI       198800
# 2  spotify:album:25hVFAxTlDvXbx2X2QkUkE       235933
# 3  spotify:album:6QPkyl04rXwTGlGlcYaRoW       267266
# 4  spotify:album:6NmFmPX56pcLBOFMhIiKvF       227600
#
#                                      album_name
# 0                                  The Cookbook
# 1                                   In The Zone
# 2  Dangerously In Love (Alben für die Ewigkeit)
# 3                                     Justified
# 4                                      Hot Shot

# %% [markdown]
# # Extracting the features from the data

# %%
data_path = 'raw_data.csv'
df2 = pd.read_csv(data_path)
# df2['track_uri'] = df2['track_uri'].apply(lambda x: re.findall(r'\w+$', x)[0]) Not necessary lmao
df2.head()
# for numrow in range(len(df)):
#     df['track_uri'][i]
print(df2.shape)
# Out:
# (67503, 10)

# %% [markdown]
# We'll add in the audio features as columns, as well as the artist's popularity, the genres of the song, and the track's popularity.

# %%
import re
def features(trackuri):
    featuredict = sp.audio_features(trackuri)[0]
    artistid = sp.track(trackuri)['artists'][0]['id']
    artistpop = sp.artist(artistid)['popularity'] # add in artist popularity
    featuredict['artistpop'] = artistpop
    trackpop = sp.track(trackuri)['popularity'] # add in track popularity
    featuredict['trackpop'] = trackpop
    genres = sp.artist(artistid)['genres']
#     genres_und = []
#     for genre in genres:
#         if ' ' in genre:
#             genres_und.append(genre.replace(' ', '_'))
#         else: genres_und.append(genre)
    if genres:
        featuredict['genres'] = ' '.join(re.sub(' ','_',genre) for genre in genres) # short version
    else: 
        featuredict['genres'] = 'unknown'

    return featuredict

# print(type(sp.artist('2wIVse2owClT7go1WT98tk')['popularity']))
# print(sp.artist('2wIVse2owClT7go1WT98tk')['genres'])
# print(sp.track('0UaMYEvWZi0ZqiDOoHU3YI')['artists'][0]['id'])
print(features('spotify:track:0UaMYEvWZi0ZqiDOoHU3YI'))
# Out:
# {'danceability': 0.904, 'energy': 0.813, 'key': 4, 'loudness': -7.105, 'mode': 0, 'speechiness': 0.121, 'acousticness': 0.0311, 'instrumentalness': 0.00697, 'liveness': 0.0471, 'valence': 0.81, 'tempo': 125.461, 'type': 'audio_features', 'id': '0UaMYEvWZi0ZqiDOoHU3YI', 'uri': 'spotify:track:0UaMYEvWZi0ZqiDOoHU3YI', 'track_href': 'https://api.spotify.com/v1/tracks/0UaMYEvWZi0ZqiDOoHU3YI', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0UaMYEvWZi0ZqiDOoHU3YI', 'duration_ms': 226864, 'time_signature': 4, 'artistpop': 70, 'trackpop': 67, 'genres': 'dance_pop hip_hop hip_pop pop pop_rap r&b rap urban_contemporary virginia_hip_hop'}

# %%
featurelist = []

for i, track in enumerate(df2['track_uri'].head(100)):
    if i%10==0: print(f'Song {i} complete')
    try: featurelist.append(features(track))
    except: continue
featuredf = pd.DataFrame(featurelist)
featuredf
# Out:
# Song 0 complete
# Song 10 complete
# Song 20 complete
# Song 30 complete
# Song 40 complete
# Song 50 complete
# Song 60 complete
# Song 70 complete
# Song 80 complete
# Song 90 complete
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.904   0.813    4    -7.105     0       0.1210       0.03110
# 1          0.774   0.838    5    -3.914     0       0.1140       0.02490
# 2          0.664   0.758    2    -6.583     0       0.2100       0.00238
# 3          0.892   0.714    4    -6.055     0       0.1410       0.20100
# 4          0.853   0.606    0    -4.596     1       0.0713       0.05610
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.539   0.846    8    -3.192     1       0.0354       0.00630
# 96         0.729   0.898    5    -1.029     1       0.0391       0.31500
# 97         0.609   0.246    8    -8.449     1       0.0376       0.78400
# 98         0.763   0.658    5    -5.643     0       0.1470       0.02580
# 99         0.604   0.875    7    -1.995     0       0.0539       0.24400
#
#     instrumentalness  liveness  valence  ...            type  \
# 0           0.006970    0.0471    0.810  ...  audio_features
# 1           0.025000    0.2420    0.924  ...  audio_features
# 2           0.000000    0.0598    0.701  ...  audio_features
# 3           0.000234    0.0521    0.817  ...  audio_features
# 4           0.000000    0.3130    0.654  ...  audio_features
# ..               ...       ...      ...  ...             ...
# 95          0.000002    0.1300    0.460  ...  audio_features
# 96          0.000000    0.1070    0.517  ...  audio_features
# 97          0.000000    0.0825    0.371  ...  audio_features
# 98          0.000000    0.0915    0.389  ...  audio_features
# 99          0.000000    0.1140    0.219  ...  audio_features
#
#                         id                                   uri  \
# 0   0UaMYEvWZi0ZqiDOoHU3YI  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1   6I9VzXrHxO9rA9A5euc8Ak  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2   0WqIKmW4BTrj3eJFmnCKMv  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3   1AWQoqb9bSvzTjaLralEkT  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4   1lzr43nnXAijIGYnCT8M8H  spotify:track:1lzr43nnXAijIGYnCT8M8H
# ..                     ...                                   ...
# 95  0WNGsQ1oAuHzNTk8jivBKW  spotify:track:0WNGsQ1oAuHzNTk8jivBKW
# 96  24psBRmEw3kHjBGZfl1dmb  spotify:track:24psBRmEw3kHjBGZfl1dmb
# 97  06L1apH8kLF47dbhZ4Zg9A  spotify:track:06L1apH8kLF47dbhZ4Zg9A
# 98  2qWgqPdW1OiAP8KSBH1b93  spotify:track:2qWgqPdW1OiAP8KSBH1b93
# 99  2PTf3zh9UUsgdxQ5b0eXg8  spotify:track:2PTf3zh9UUsgdxQ5b0eXg8
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/0UaMYEvWZi0Z...
# 1   https://api.spotify.com/v1/tracks/6I9VzXrHxO9r...
# 2   https://api.spotify.com/v1/tracks/0WqIKmW4BTrj...
# 3   https://api.spotify.com/v1/tracks/1AWQoqb9bSvz...
# 4   https://api.spotify.com/v1/tracks/1lzr43nnXAij...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/0WNGsQ1oAuHz...
# 96  https://api.spotify.com/v1/tracks/24psBRmEw3kH...
# 97  https://api.spotify.com/v1/tracks/06L1apH8kLF4...
# 98  https://api.spotify.com/v1/tracks/2qWgqPdW1OiA...
# 99  https://api.spotify.com/v1/tracks/2PTf3zh9UUsg...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/0UaM...      226864
# 1   https://api.spotify.com/v1/audio-analysis/6I9V...      198800
# 2   https://api.spotify.com/v1/audio-analysis/0WqI...      235933
# 3   https://api.spotify.com/v1/audio-analysis/1AWQ...      267267
# 4   https://api.spotify.com/v1/audio-analysis/1lzr...      227600
# ..                                                ...         ...
# 95  https://api.spotify.com/v1/audio-analysis/0WNG...      274097
# 96  https://api.spotify.com/v1/audio-analysis/24ps...      218475
# 97  https://api.spotify.com/v1/audio-analysis/06L1...      288993
# 98  https://api.spotify.com/v1/audio-analysis/2qWg...      217861
# 99  https://api.spotify.com/v1/audio-analysis/2PTf...      234107
#
#     time_signature  artistpop  trackpop  \
# 0                4         70        67
# 1                4         80        81
# 2                4         88        21
# 3                4         80        76
# 4                4         72         0
# ..             ...        ...       ...
# 95               4         91         2
# 96               4         42         0
# 97               4         65         0
# 98               4         65         0
# 99               4         56         0
#
#                                                genres
# 0   dance_pop hip_hop hip_pop pop pop_rap r&b rap ...
# 1                         dance_pop pop post-teen_pop
# 2                                   dance_pop pop r&b
# 3                                       dance_pop pop
# 4                               pop_rap reggae_fusion
# ..                                                ...
# 95                              k-pop k-pop_boy_group
# 96                             k-pop k-pop_girl_group
# 97                                              k-pop
# 98                                              k-pop
# 99                                   k-pop korean_pop
#
# [100 rows x 21 columns]

# %%
df2small = df2.head(100)
final_100 = pd.merge(df2small, featuredf, how='outer')
final_100
# Out:
#      Unnamed: 0  pos        artist_name                             track_uri  \
# 0           0.0  0.0      Missy Elliott  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1           1.0  1.0     Britney Spears  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2           2.0  2.0            Beyoncé  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3           3.0  3.0  Justin Timberlake  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4           4.0  4.0             Shaggy  spotify:track:1lzr43nnXAijIGYnCT8M8H
# ..          ...  ...                ...                                   ...
# 130         NaN  NaN                NaN                                   NaN
# 131         NaN  NaN                NaN                                   NaN
# 132         NaN  NaN                NaN                                   NaN
# 133         NaN  NaN                NaN                                   NaN
# 134         NaN  NaN                NaN                                   NaN
#
#                                 artist_uri  \
# 0    spotify:artist:2wIVse2owClT7go1WT98tk
# 1    spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 2    spotify:artist:6vWDO969PvNqNYHIOW5v0m
# 3    spotify:artist:31TPClRtHm23RisEBtV3X7
# 4    spotify:artist:5EvFsr3kj42KNv97ZEnqij
# ..                                     ...
# 130                                    NaN
# 131                                    NaN
# 132                                    NaN
# 133                                    NaN
# 134                                    NaN
#
#                                      track_name  \
# 0    Lose Control (feat. Ciara & Fat Man Scoop)
# 1                                         Toxic
# 2                                 Crazy In Love
# 3                                Rock Your Body
# 4                                  It Wasn't Me
# ..                                          ...
# 130                                         NaN
# 131                                         NaN
# 132                                         NaN
# 133                                         NaN
# 134                                         NaN
#
#                                 album_uri  duration_ms  \
# 0    spotify:album:6vV5UrXcfyQD1wu4Qo2I9K       226863
# 1    spotify:album:0z7pVBGOD7HCIB7S8eLkLI       198800
# 2    spotify:album:25hVFAxTlDvXbx2X2QkUkE       235933
# 3    spotify:album:6QPkyl04rXwTGlGlcYaRoW       267266
# 4    spotify:album:6NmFmPX56pcLBOFMhIiKvF       227600
# ..                                    ...          ...
# 130                                   NaN       180007
# 131                                   NaN       232867
# 132                                   NaN       218475
# 133                                   NaN       288993
# 134                                   NaN       234107
#
#                                        album_name        name  ...    tempo  \
# 0                                    The Cookbook  Throwbacks  ...      NaN
# 1                                     In The Zone  Throwbacks  ...  143.040
# 2    Dangerously In Love (Alben für die Ewigkeit)  Throwbacks  ...   99.259
# 3                                       Justified  Throwbacks  ...      NaN
# 4                                        Hot Shot  Throwbacks  ...   94.759
# ..                                            ...         ...  ...      ...
# 130                                           NaN         NaN  ...   96.959
# 131                                           NaN         NaN  ...  144.111
# 132                                           NaN         NaN  ...  126.977
# 133                                           NaN         NaN  ...  123.773
# 134                                           NaN         NaN  ...  129.925
#
#                type                      id  \
# 0               NaN                     NaN
# 1    audio_features  6I9VzXrHxO9rA9A5euc8Ak
# 2    audio_features  0WqIKmW4BTrj3eJFmnCKMv
# 3               NaN                     NaN
# 4    audio_features  1lzr43nnXAijIGYnCT8M8H
# ..              ...                     ...
# 130  audio_features  4erhEGuOGQgjv3p1bccnpn
# 131  audio_features  1enx9LPZrXxaVVBxas5rRm
# 132  audio_features  24psBRmEw3kHjBGZfl1dmb
# 133  audio_features  06L1apH8kLF47dbhZ4Zg9A
# 134  audio_features  2PTf3zh9UUsgdxQ5b0eXg8
#
#                                       uri  \
# 0                                     NaN
# 1    spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2    spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3                                     NaN
# 4    spotify:track:1lzr43nnXAijIGYnCT8M8H
# ..                                    ...
# 130  spotify:track:4erhEGuOGQgjv3p1bccnpn
# 131  spotify:track:1enx9LPZrXxaVVBxas5rRm
# 132  spotify:track:24psBRmEw3kHjBGZfl1dmb
# 133  spotify:track:06L1apH8kLF47dbhZ4Zg9A
# 134  spotify:track:2PTf3zh9UUsgdxQ5b0eXg8
#
#                                             track_href  \
# 0                                                  NaN
# 1    https://api.spotify.com/v1/tracks/6I9VzXrHxO9r...
# 2    https://api.spotify.com/v1/tracks/0WqIKmW4BTrj...
# 3                                                  NaN
# 4    https://api.spotify.com/v1/tracks/1lzr43nnXAij...
# ..                                                 ...
# 130  https://api.spotify.com/v1/tracks/4erhEGuOGQgj...
# 131  https://api.spotify.com/v1/tracks/1enx9LPZrXxa...
# 132  https://api.spotify.com/v1/tracks/24psBRmEw3kH...
# 133  https://api.spotify.com/v1/tracks/06L1apH8kLF4...
# 134  https://api.spotify.com/v1/tracks/2PTf3zh9UUsg...
#
#                                           analysis_url  time_signature  \
# 0                                                  NaN             NaN
# 1    https://api.spotify.com/v1/audio-analysis/6I9V...             4.0
# 2    https://api.spotify.com/v1/audio-analysis/0WqI...             4.0
# 3                                                  NaN             NaN
# 4    https://api.spotify.com/v1/audio-analysis/1lzr...             4.0
# ..                                                 ...             ...
# 130  https://api.spotify.com/v1/audio-analysis/4erh...             4.0
# 131  https://api.spotify.com/v1/audio-analysis/1enx...             4.0
# 132  https://api.spotify.com/v1/audio-analysis/24ps...             4.0
# 133  https://api.spotify.com/v1/audio-analysis/06L1...             4.0
# 134  https://api.spotify.com/v1/audio-analysis/2PTf...             4.0
#
#      artistpop  trackpop                       genres
# 0          NaN       NaN                          NaN
# 1         80.0      81.0  dance_pop pop post-teen_pop
# 2         88.0      21.0            dance_pop pop r&b
# 3          NaN       NaN                          NaN
# 4         72.0       0.0        pop_rap reggae_fusion
# ..         ...       ...                          ...
# 130       62.0      35.0             k-pop korean_r&b
# 131       37.0      50.0                      unknown
# 132       42.0       0.0       k-pop k-pop_girl_group
# 133       65.0       0.0                        k-pop
# 134       56.0       0.0             k-pop korean_pop
#
# [135 rows x 30 columns]
